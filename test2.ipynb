# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Fetch stock price for Celltrion for recent 10 days
celltrion = yf.Ticker("068270.KS")
celltrion_data = celltrion.history(period="10d")

print(celltrion_data)
# Out:
#                                Open      High       Low     Close   Volume  \
# Date
# 2025-09-23 00:00:00+09:00  168700.0  185400.0  168600.0  184200.0  2543427
# 2025-09-24 00:00:00+09:00  184200.0  184200.0  174200.0  176900.0  1061295
# 2025-09-25 00:00:00+09:00  177000.0  179400.0  176400.0  177900.0   540443
# 2025-09-26 00:00:00+09:00  180700.0  181500.0  176000.0  178000.0   887114
# 2025-09-29 00:00:00+09:00  180000.0  181600.0  178050.0  178600.0   440827
# 2025-09-30 00:00:00+09:00  177500.0  177500.0  173100.0  173400.0   565425
# 2025-10-01 00:00:00+09:00  175000.0  176700.0  174100.0  175100.0   327878
# 2025-10-02 00:00:00+09:00  175400.0  177000.0  174300.0  175800.0   558334
# 2025-10-10 00:00:00+09:00       0.0       0.0       0.0  173600.0        0
#
#                            Dividends  Stock Splits
# Date
# 2025-09-23 00:00:00+09:00        0.0           0.0
# 2025-09-24 00:00:00+09:00        0.0           0.0
# 2025-09-25 00:00:00+09:00        0.0           0.0
# 2025-09-26 00:00:00+09:00        0.0           0.0
# 2025-09-29 00:00:00+09:00        0.0           0.0
# 2025-09-30 00:00:00+09:00        0.0           0.0
# 2025-10-01 00:00:00+09:00        0.0           0.0
# 2025-10-02 00:00:00+09:00        0.0           0.0
# 2025-10-10 00:00:00+09:00        0.0           0.0

# %%
#Visualize this data
plt.figure(figsize=(10, 5))
plt.plot(celltrion_data["Close"], label="Celltrion")
plt.title("Celltrion Stock Price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()
